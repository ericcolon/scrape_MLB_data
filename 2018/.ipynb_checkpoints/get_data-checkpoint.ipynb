# %%
from bs4 import BeautifulSoup
from datetime import datetime
import urllib2
import pandas as pd
from settings import *
#from get_pts import *
from time import sleep
#from get_schedule_results import append_opposing_pitcher
#from get_opposing_pitcher_info import append_pitcher_data
#from feature_engineering import *
from os import listdir
import numpy as np
import warnings
from tqdm import tqdm
warnings.filterwarnings('ignore')

# %%
#Scrape a players career stats from baseball reference
def scrape_career_data(url):
    soup = BeautifulSoup(urllib2.urlopen(url).read(),"html.parser") 
    tableStats = soup.find("table",{"id":"batting_standard"}).find('tfoot')
    rows = tableStats.findAll('tr',{'class':'stat_total'})
    data = []
    for row in rows[:2]:
        current = []
        for col in row:
            if col.name == 'td':
                current.append(col.string)
        data.append(current)
    cols = ['Year','G','PA','AB','R','H','2B','3B','HR','RBI','SB','CS','BB','SO','BA','OBP','SLG','OPS','OPS+','TB','GDP','HBP','SH','SF','IBB','Pos','Awards']
    df = pd.DataFrame(data,columns=cols)
    return df

# %%
def get_hitter_data(url):
    #print 'Scraping hitter data...'
    
    soup = BeautifulSoup(urllib2.urlopen(url).read(),"html.parser") 
    tableStats = soup.find("table",{"class":"dbd"})
    rows = tableStats.findAll('tr')
    
    #column names are in first row; they have extra space fields so remove those
    col_names = [x.string for x in rows[0] if x.string != ' ']    
    
    #iterate thru each row getting the data from each td tag
    #then append each row to a list containing all data rows
    data_rows = []
    for row in rows[:-1]:
        current = []
        for col in row:
            if col.name == 'td':
                current.append(str(col.string))
        data_rows.append(current)
            
    #create dataframe and drop empty rows
    df = pd.DataFrame(data_rows,columns=col_names)
    df1 = df.dropna().reset_index(drop=True)
    
    #Append batting style
    bats = str(soup.find('h5').text).split()[1][0]
    df1['bats'] = bats
    
    #change dtypes to ints where possible
    for column in df1:
        try:
            df1[column] = df1[column].astype(int)
        except:
            pass
    
    return df1

# %%
def scrape_game_log(url):
    soup = BeautifulSoup(urllib2.urlopen(url).read(),"html.parser") 
    tableStats = soup.find("table",{"id":"batting_gamelogs"}).find('tbody')
    rows = tableStats.findAll('tr')
    tableHead = soup.find("table",{"id":"batting_gamelogs"}).find('thead').find('tr')
    col_names = [x.string for x in tableHead if x.name == 'th']
    
    data = []
    for row in rows:
        current = [col.string for col in row if col.name == 'td']
        data.append(current)
    df = pd.DataFrame(data,columns=col_names)
    def convert_date(d):
        try:
            return datetime.strptime(d,'%b %d').strftime('2016-%m-%d')
        except:
            return None
    df['Date'] = df['Date'].apply(lambda x: convert_date(x))

    return df

# %% [markdown]
# ### 1. Get Hitter Data
#
# #### Right now we only have 279 unique players- need more

# %%
all_hitter_data = []
for player,url in tqdm(players_urls0.iteritems()):
    url = players_urls0[player]
    hitter_data = get_hitter_data(url)
    hitter_data['hitter_name'] = player
    all_hitter_data.append(hitter_data)
    #print 'Got {}'.format(player)
    sleep(np.random.rand())
    
all_hitter_data1 = pd.concat(all_hitter_data)

# %%
#hitter_data = get_hitter_data(url)

# %%
def append_hitter_score_to_df(df):
    #print 'Calculating draftkings points...'
    s = (df['Hits'] - (df['2B'] + df['3B'] + df['HR'])) * 3
    d = df['2B'] * 5
    t = df['3B'] * 8
    hr = df['HR'] * 10
    rbi = df['RBI'] * 2
    r = df['Runs'] * 2
    bb = df['BB'] * 2
    hbp = df['HBP'] * 2 
    sb = df['SB'] * 5
    df['FANTASY_PTS'] = s+d+t+hr+rbi+r+bb+hbp+sb
    return df

all_hitter_data2 = append_hitter_score_to_df(all_hitter_data1)

# %%
all_hitter_data2.shape

# %%
all_hitter_data2.to_csv('_data/hitter_data_2016/hitter_data_2016.csv',index=False)

# %% [markdown]
# ### Get Game Logs

# %%
#url = players_game_logs0['Mookie_Betts']

# %%
#soup = BeautifulSoup(urllib2.urlopen(url).read(),"html.parser") 
#tableStats = soup.find("table",{"id":"batting_gamelogs"}).find('tbody')
#rows = tableStats.findAll('tr')
#tableHead = soup.find("table",{"id":"batting_gamelogs"}).find('thead').find('tr')
#col_names = [x.string for x in tableHead if x.name == 'th']

# %%
# data = []
# for row in rows:
#     current = [col.string for col in row if col.name in ('td','th')]
#     data.append(current)
# df = pd.DataFrame(data,columns=col_names)
# def convert_date(d):
#     try:
#         return datetime.strptime(d,'%b %d').strftime('2016-%m-%d')
#     except:
#         return None
# df['Date'] = df['Date'].apply(lambda x: convert_date(x))

# %%
# df.to_csv('_data/game_logs/game_logs.csv',encoding='utf-8',index=False)

# %% [markdown]
# ### 2. Append Opposing Pitcher

# %%
all_hitter_data2.shape

# %%
schedules = pd.read_csv('_data/schedules_2016/_ALL_SCHEDULES_2016.csv')

# %%
def append_opposing_pitcher(hitter_df,schedule_df):
    #Reformat hitter dates
    hitter_df['Game Date'] = hitter_df['Game Date'].apply(lambda x: x.replace('\\r\\n','').strip())
    hitter_df['Game Date'] = pd.to_datetime(hitter_df['Game Date'],format="%m/%d/%Y",errors='coerce')
    schedule_df['Date'] = pd.to_datetime(schedule_df['Date'],format="%m/%d/%Y",errors='coerce')
    
    df1 = pd.merge(hitter_df,schedule_df[['Date','Opp','opp_pitcher','Gm#','Team']],how='left',
                   left_on=['Team','Game Date'],right_on=['Team','Date'])
    df1.dropna(inplace=True)
    return df1

# %%
all_hitter_data3 = append_opposing_pitcher(all_hitter_data2.copy(),schedules)

# %%
all_hitter_data3.head()

# %%
all_hitter_data3.to_csv('_data/hitter_data_2016/hitter_data_2016_w_pitcher.csv',index=False)

# %% [markdown]
# ### 3. Do the same things for 2017

# %%
#Create players urls for 2017
players_urls_2017 = {}
for player, url in players_urls0.iteritems():
    players_urls_2017[player] = players_urls0[player].replace('F2016','F2017')

# %%
all_hitter_data_2017 = []
for player,url in tqdm(players_urls_2017.iteritems()):
    url = players_urls_2017[player]
    
    try:
        hitter_data = get_hitter_data(url)
    except:
        print 'Problem with {} for 2017'.format(player)
        continue
        
    hitter_data['hitter_name'] = player
    all_hitter_data_2017.append(hitter_data)
    #print 'Got {}'.format(player)
    sleep(np.random.rand())
    
all_hitter_data1 = pd.concat(all_hitter_data_2017)
# Out:
# 27it [00:30,  1.04it/s]
# Problem with Dae-Ho_Lee for 2017
# 29it [00:32,  1.10it/s]
# Problem with Coco_Crisp for 2017
# 43it [00:47,  1.36it/s]
# Problem with Mark_Teixeira for 2017
# 66it [01:10,  1.02it/s]
# Problem with Jimmy_Rollins for 2017
# 69it [01:12,  1.40it/s]
# Problem with Byung-Ho_Park for 2017
# 99it [01:43,  1.24it/s]
# Problem with Ryan_Howard for 2017
# 105it [01:48,  1.40it/s]
# Problem with Alexei_Ramirez for 2017
# 134it [02:23,  1.05it/s]
# Problem with James_Loney for 2017
# 150it [02:39,  1.42it/s]
# Problem with Angel_Pagan for 2017
# 152it [02:40,  1.63it/s]
# Problem with Michael_Bourn for 2017
# 153it [02:41,  1.93it/s]
# Problem with Juan_Uribe for 2017
# 199it [03:31,  1.21it/s]
# Problem with Ortiz for 2017
# 206it [03:38,  1.19it/s]
# Problem with Brett_Lawrie for 2017
# 208it [03:40,  1.43it/s]
# Problem with Alex_Rodriguez for 2017
# 236it [04:13,  1.03it/s]
# Problem with Dioner_Navarro for 2017
# 242it [04:19,  1.14it/s]
# Problem with Prince_Fielder for 2017
# 252it [04:30,  1.08it/s]
# Problem with David_Ross for 2017
# 260it [04:37,  1.18it/s]
# Problem with Gregorio_Petit for 2017
# 268it [04:45,  1.23it/s]
# Problem with Jung-ho Kang for 2017
# 279it [04:59,  1.29s/it]

# %%
def append_hitter_score_to_df(df):
    #print 'Calculating draftkings points...'
    s = (df['Hits'] - (df['2B'] + df['3B'] + df['HR'])) * 3
    d = df['2B'] * 5
    t = df['3B'] * 8
    hr = df['HR'] * 10
    rbi = df['RBI'] * 2
    r = df['Runs'] * 2
    bb = df['BB'] * 2
    hbp = df['HBP'] * 2 
    sb = df['SB'] * 5
    df['FANTASY_PTS'] = s+d+t+hr+rbi+r+bb+hbp+sb
    return df

all_hitter_data2 = append_hitter_score_to_df(all_hitter_data1)

# %%
all_hitter_data2.to_csv('_data/hitter_data/hitter_data_2017.csv',index=False)

# %%
schedules = pd.read_csv('_data/schedules/_ALL_SCHEDULES_2017.csv')

# %%
all_hitter_data2.head()
# Out:
#       Game Date Team Opponent  GS  AB  Runs  Hits  2B  3B  HR     ...       K  \
# 0  04/02/2017\n  SLN  Vs. CHN   1   2     0     0   0   0   0     ...       1
# 1  04/06/2017\n  SLN  Vs. CHN   1   4     0     0   0   0   0     ...       2
# 2  04/08/2017\n  SLN  Vs. CIN   1   3     1     2   1   0   0     ...       1
# 3  04/09/2017\n  SLN  Vs. CIN   1   3     0     0   0   0   0     ...       0
# 4  04/10/2017\n  SLN   At WSH   0   2     1     1   0   0   1     ...       0
#
#    SB  CS  SH  SF  GDP  CI  bats  hitter_name  FANTASY_PTS
# 0   0   0   0   0    0   0     R  Jedd_Gyorko            0
# 1   0   0   0   0    0   0     R  Jedd_Gyorko            0
# 2   0   0   0   0    0   0     R  Jedd_Gyorko           18
# 3   0   0   0   0    0   0     R  Jedd_Gyorko            0
# 4   0   0   0   0    0   0     R  Jedd_Gyorko           14
#
# [5 rows x 24 columns]

# %%
schedules.head()
# Out:
#    Unnamed: 0  Opp opp_pitcher  Gm# Team        Date
# 0           0  SFG    Melancon    1  ARI  04/02/2017
# 1           2  SFG       Moore    3  ARI  04/05/2017
# 2           3  SFG  Samardzija    4  ARI  04/06/2017
# 3           4  CLE      Tomlin    5  ARI  04/07/2017
# 4           5  CLE       Bauer    6  ARI  04/08/2017

# %%
#pd.to_datetime(schedules['Date'],format="%m/%d/%Y",errors='coerce')

# %%
def append_opposing_pitcher(hitter_df,schedule_df):
    #Reformat hitter dates
    hitter_df['Game Date'] = hitter_df['Game Date'].apply(lambda x: x.replace('\\r\\n','').strip())
    hitter_df['Game Date'] = pd.to_datetime(hitter_df['Game Date'],format="%m/%d/%Y",errors='coerce')
    schedule_df['Date'] = pd.to_datetime(schedule_df['Date'],format="%m/%d/%Y",errors='coerce')
    
    df1 = pd.merge(hitter_df,schedule_df[['Date','Opp','opp_pitcher','Gm#','Team']],how='left',
                   left_on=['Team','Game Date'],right_on=['Team','Date'])
    df1.dropna(inplace=True)
    return df1

# %%
all_hitter_data3 = append_opposing_pitcher(all_hitter_data2.copy(),schedules)

# %%
all_hitter_data3
# Out:
#        Game Date Team Opponent  GS  AB  Runs  Hits  2B  3B  HR  ...    SF  \
# 0     2017-04-02  SLN  Vs. CHN   1   2     0     0   0   0   0  ...     0
# 1     2017-04-06  SLN  Vs. CHN   1   4     0     0   0   0   0  ...     0
# 2     2017-04-08  SLN  Vs. CIN   1   3     1     2   1   0   0  ...     0
# 3     2017-04-09  SLN  Vs. CIN   1   3     0     0   0   0   0  ...     0
# 4     2017-04-10  SLN   At WSH   0   2     1     1   0   0   1  ...     0
# 5     2017-04-11  SLN   At WSH   1   4     0     1   0   0   0  ...     0
# 6     2017-04-12  SLN   At WSH   1   4     0     1   0   0   0  ...     0
# 7     2017-04-15  SLN   At NYA   1   3     1     1   0   0   1  ...     0
# 8     2017-04-16  SLN   At NYA   1   3     1     1   0   0   0  ...     0
# 9     2017-04-18  SLN  Vs. PIT   0   1     0     0   0   0   0  ...     0
# 10    2017-04-19  SLN  Vs. PIT   1   2     0     0   0   0   0  ...     0
# 11    2017-04-20  SLN   At MIL   1   3     2     3   2   0   1  ...     0
# 12    2017-04-21  SLN   At MIL   1   4     1     2   0   0   0  ...     0
# 13    2017-04-22  SLN   At MIL   1   4     1     1   0   1   0  ...     0
# 14    2017-04-25  SLN  Vs. TOR   1   5     0     3   1   0   0  ...     0
# 23    2017-04-28  SLN  Vs. CIN   1   4     2     2   0   0   1  ...     0
# 24    2017-04-30  SLN  Vs. CIN   1   4     0     2   1   0   0  ...     0
# 25    2017-05-01  SLN  Vs. MIL   1   5     2     4   0   0   2  ...     0
# 26    2017-05-02  SLN  Vs. MIL   1   4     0     0   0   0   0  ...     0
# 27    2017-05-04  SLN  Vs. MIL   1   5     0     1   0   0   0  ...     0
# 28    2017-05-05  SLN   At ATL   1   4     1     2   1   0   0  ...     0
# 29    2017-05-06  SLN   At ATL   0   1     0     1   0   0   0  ...     0
# 30    2017-05-07  SLN   At ATL   1   5     0     1   1   0   0  ...     0
# 31    2017-05-08  SLN   At MIA   1   5     0     1   1   0   0  ...     0
# 32    2017-05-09  SLN   At MIA   1   4     0     1   0   0   0  ...     0
# 33    2017-05-10  SLN   At MIA   1   4     1     3   0   0   0  ...     0
# 34    2017-05-12  SLN  Vs. CHN   1   3     0     0   0   0   0  ...     0
# 35    2017-05-13  SLN  Vs. CHN   1   4     1     1   0   0   1  ...     0
# 36    2017-05-14  SLN  Vs. CHN   1   4     1     1   0   0   0  ...     0
# 37    2017-05-16  SLN  Vs. BOS   1   4     0     1   0   0   0  ...     0
# ...          ...  ...      ...  ..  ..   ...   ...  ..  ..  ..  ...    ..
# 33929 2017-08-27  SFN   At ARI   1   2     0     0   0   0   0  ...     0
# 33930 2017-08-28  SFN   At SDN   1   2     1     1   0   0   1  ...     0
# 33931 2017-08-29  SFN   At SDN   1   4     2     2   0   0   1  ...     0
# 33932 2017-08-30  SFN   At SDN   1   3     0     0   0   0   0  ...     0
# 33933 2017-08-31  SFN  Vs. SLN   1   4     0     0   0   0   0  ...     0
# 33934 2017-09-01  SFN  Vs. SLN   1   5     0     0   0   0   0  ...     0
# 33935 2017-09-02  SFN  Vs. SLN   1   3     0     1   0   0   0  ...     0
# 33936 2017-09-03  SFN  Vs. SLN   1   3     1     1   1   0   0  ...     0
# 33937 2017-09-04  SFN   At COL   1   4     1     3   0   0   1  ...     0
# 33938 2017-09-05  SFN   At COL   1   5     0     4   1   0   0  ...     0
# 33939 2017-09-06  SFN   At COL   1   6     3     5   2   0   0  ...     0
# 33940 2017-09-08  SFN   At CHA   1   4     1     1   0   0   0  ...     0
# 33941 2017-09-09  SFN   At CHA   1   2     0     0   0   0   0  ...     0
# 33942 2017-09-10  SFN   At CHA   1   3     0     0   0   0   0  ...     0
# 33943 2017-09-11  SFN  Vs. LAN   1   3     1     1   0   0   0  ...     0
# 33944 2017-09-12  SFN  Vs. LAN   1   5     0     3   0   0   0  ...     0
# 33945 2017-09-13  SFN  Vs. LAN   0   1     0     0   0   0   0  ...     0
# 33946 2017-09-15  SFN  Vs. ARI   1   4     1     2   1   0   0  ...     0
# 33947 2017-09-16  SFN  Vs. ARI   1   3     0     1   0   0   0  ...     0
# 33948 2017-09-17  SFN  Vs. ARI   1   4     2     2   0   0   0  ...     0
# 33949 2017-09-19  SFN  Vs. COL   1   3     0     0   0   0   0  ...     0
# 33950 2017-09-20  SFN  Vs. COL   1   4     2     3   1   1   0  ...     0
# 33951 2017-09-22  SFN   At LAN   1   3     0     1   0   0   0  ...     0
# 33952 2017-09-23  SFN   At LAN   1   4     0     0   0   0   0  ...     0
# 33953 2017-09-25  SFN   At ARI   1   4     0     0   0   0   0  ...     1
# 33954 2017-09-26  SFN   At ARI   1   3     0     1   0   0   0  ...     1
# 33955 2017-09-27  SFN   At ARI   1   3     1     0   0   0   0  ...     0
# 33956 2017-09-29  SFN  Vs. SDN   1   5     2     4   1   0   0  ...     0
# 33957 2017-09-30  SFN  Vs. SDN   1   4     0     0   0   0   0  ...     0
# 33958 2017-10-01  SFN  Vs. SDN   1   4     0     1   0   0   0  ...     0
#
#        GDP  CI  bats  hitter_name  FANTASY_PTS       Date  Opp  opp_pitcher  \
# 0        0   0     R  Jedd_Gyorko            0 2017-04-02  CHC   Montgomery
# 1        0   0     R  Jedd_Gyorko            0 2017-04-06  CHC       Lackey
# 2        0   0     R  Jedd_Gyorko           18 2017-04-08  CIN       Arroyo
# 3        0   0     R  Jedd_Gyorko            0 2017-04-09  CIN      Feldman
# 4        0   0     R  Jedd_Gyorko           14 2017-04-10  WSN        Roark
# 5        0   0     R  Jedd_Gyorko            3 2017-04-11  WSN     Gonzalez
# 6        0   0     R  Jedd_Gyorko            8 2017-04-12  WSN     Scherzer
# 7        0   0     R  Jedd_Gyorko           14 2017-04-15  NYY     Sabathia
# 8        0   0     R  Jedd_Gyorko            7 2017-04-16  NYY       Pineda
# 9        0   0     R  Jedd_Gyorko            0 2017-04-18  PIT         Kuhl
# 10       0   0     R  Jedd_Gyorko            2 2017-04-19  PIT         Cole
# 11       0   0     R  Jedd_Gyorko           28 2017-04-20  MIL       Davies
# 12       0   0     R  Jedd_Gyorko            8 2017-04-21  MIL      Peralta
# 13       0   0     R  Jedd_Gyorko           14 2017-04-22  MIL       Torres
# 14       0   0     R  Jedd_Gyorko           13 2017-04-25  TOR       Grilli
# 23       0   0     R  Jedd_Gyorko           19 2017-04-28  CIN      Adleman
# 24       0   0     R  Jedd_Gyorko            8 2017-04-30  CIN      Peralta
# 25       0   0     R  Jedd_Gyorko           34 2017-05-01  MIL        Drake
# 26       0   0     R  Jedd_Gyorko            0 2017-05-02  MIL      Peralta
# 27       0   0     R  Jedd_Gyorko            3 2017-05-04  MIL        Drake
# 28       0   0     R  Jedd_Gyorko           12 2017-05-05  ATL  Foltynewicz
# 29       0   0     R  Jedd_Gyorko            3 2017-05-06  ATL      Teheran
# 30       0   0     R  Jedd_Gyorko            9 2017-05-07  ATL   Collmenter
# 31       0   0     R  Jedd_Gyorko            7 2017-05-08  MIA       Conley
# 32       1   0     R  Jedd_Gyorko            7 2017-05-09  MIA        Ramos
# 33       0   0     R  Jedd_Gyorko           22 2017-05-10  MIA       Garcia
# 34       0   0     R  Jedd_Gyorko            2 2017-05-12  CHC       Butler
# 35       0   0     R  Jedd_Gyorko           14 2017-05-13  CHC       Lester
# 36       0   0     R  Jedd_Gyorko            5 2017-05-14  CHC      Arrieta
# 37       0   0     R  Jedd_Gyorko            3 2017-05-16  BOS    Rodriguez
# ...    ...  ..   ...          ...          ...        ...  ...          ...
# 33929    0   0     L    Joe_Panik            2 2017-08-27  ARI       Corbin
# 33930    0   0     L    Joe_Panik           20 2017-08-28  SDP       Chacin
# 33931    0   0     L    Joe_Panik           19 2017-08-29  SDP      Perdomo
# 33932    0   0     L    Joe_Panik            2 2017-08-30  SDP      Stammen
# 33933    0   0     L    Joe_Panik            0 2017-08-31  STL        Wacha
# 33934    0   0     L    Joe_Panik            0 2017-09-01  STL        Lyons
# 33935    0   0     L    Joe_Panik            3 2017-09-02  STL     Sherriff
# 33936    0   0     L    Joe_Panik            9 2017-09-03  STL       Weaver
# 33937    0   0     L    Joe_Panik           22 2017-09-04  COL      Holland
# 33938    0   0     L    Joe_Panik           16 2017-09-05  COL        Rusin
# 33939    0   0     L    Joe_Panik           29 2017-09-06  COL     Freeland
# 33940    0   0     L    Joe_Panik            7 2017-09-08  CHW      Giolito
# 33941    0   0     L    Joe_Panik            2 2017-09-09  CHW      Shields
# 33942    0   0     L    Joe_Panik            2 2017-09-10  CHW       Fulmer
# 33943    0   0     L    Joe_Panik            7 2017-09-11  LAD         Baez
# 33944    0   0     L    Joe_Panik            9 2017-09-12  LAD      Kershaw
# 33945    0   0     L    Joe_Panik            0 2017-09-13  LAD      Darvish
# 33946    1   0     L    Joe_Panik           10 2017-09-15  ARI          Ray
# 33947    0   0     L    Joe_Panik            5 2017-09-16  ARI      Greinke
# 33948    0   0     L    Joe_Panik           10 2017-09-17  ARI       Walker
# 33949    0   0     L    Joe_Panik            2 2017-09-19  COL        Rusin
# 33950    0   0     L    Joe_Panik           22 2017-09-20  COL     Chatwood
# 33951    0   0     L    Joe_Panik            5 2017-09-22  LAD         Hill
# 33952    0   0     L    Joe_Panik            0 2017-09-23  LAD          Ryu
# 33953    0   0     L    Joe_Panik            2 2017-09-25  ARI       Godley
# 33954    0   0     L    Joe_Panik            5 2017-09-26  ARI          Ray
# 33955    0   0     L    Joe_Panik            4 2017-09-27  ARI       Hoover
# 33956    0   0     L    Joe_Panik           20 2017-09-29  SDP        Lyles
# 33957    0   0     L    Joe_Panik            2 2017-09-30  SDP      Baumann
# 33958    0   0     L    Joe_Panik            3 2017-10-01  SDP        Maton
#
#          Gm#
# 0        1.0
# 1        3.0
# 2        5.0
# 3        6.0
# 4        7.0
# 5        8.0
# 6        9.0
# 7       11.0
# 8       12.0
# 9       14.0
# 10      15.0
# 11      16.0
# 12      17.0
# 13      18.0
# 14      20.0
# 23      23.0
# 24      24.0
# 25      25.0
# 26      26.0
# 27      27.0
# 28      28.0
# 29      29.0
# 30      30.0
# 31      31.0
# 32      32.0
# 33      33.0
# 34      34.0
# 35      35.0
# 36      36.0
# 37      37.0
# ...      ...
# 33929  132.0
# 33930  133.0
# 33931  134.0
# 33932  135.0
# 33933  136.0
# 33934  137.0
# 33935  138.0
# 33936  139.0
# 33937  140.0
# 33938  141.0
# 33939  142.0
# 33940  143.0
# 33941  144.0
# 33942  145.0
# 33943  146.0
# 33944  147.0
# 33945  148.0
# 33946  149.0
# 33947  150.0
# 33948  151.0
# 33949  152.0
# 33950  153.0
# 33951  154.0
# 33952  155.0
# 33953  157.0
# 33954  158.0
# 33955  159.0
# 33956  160.0
# 33957  161.0
# 33958  162.0
#
# [29512 rows x 28 columns]

# %%
all_hitter_data3.to_csv('_data/hitter_data/hitter_data_2017_w_pitcher.csv',index=False)

# %% [markdown]
# ### 3. Append Ballpark
